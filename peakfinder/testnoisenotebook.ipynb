# %%
import numpy as np
import noisegenerator as ng
import matplotlib.pyplot as plt

x = np.linspace(-20,20,2000)
x2 = 2000*np.exp(- (x)**2) + 2000*np.exp(- (x-15)**2)
y = ng.noisegen(x2,2,500)
print(y[200])



plt.plot(x,y)
plt.show()
# Out:
# 1013.2392042
